# %% [markdown]
# <a href="https://colab.research.google.com/github/dansonnganga039-spec/whatever-data-science/blob/main/Friday_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Dropout & At-Risk Learner Predictor

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("thedevastator/higher-education-predictors-of-student-retention")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 87.2k/87.2k [00:00<00:00, 746kB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/thedevastator/higher-education-predictors-of-student-retention/versions/2

# %% [markdown]
# The "higher-education-predictors-of-student-retention" dataset from Kaggle focuses on analyzing factors influencing student dropout and academic success in higher education.^1_1
#
# #Main Objective
# - The primary goal is to investigate the impact of demographic, social-economic, and academic performance factors on student dropout rates and academic outcomes using data from undergraduate students at a higher education institution.
#
# ##Specific Objectives
# - Develop predictive models to identify risk factors for student dropout and enable early interventions for better retention.
# - Understand interactions between features, such as demographic characteristics (e.g., age, gender) and economic conditions (e.g., unemployment rate), to inform student success strategies.
# - Assess academic progress through metrics like curricular units and grades to guide institutional improvements in performance and accessibility.
#
#
# ##Additional Objectives
# - Identify specific predictive factors linked to student dropout, completion, or enrollment continuation.
# - Analyze interactions between features, like demographics (gender, age), economic indicators (unemployment, inflation), and academic metrics.
# - Explore associations between student characteristics (e.g., nationality, parental qualifications) and outcomes to address biases and underrepresented groups.
# - Estimate semester-end performance trends using curricular units (credited, enrolled, approved, grades) for institutional strategy formulation.
